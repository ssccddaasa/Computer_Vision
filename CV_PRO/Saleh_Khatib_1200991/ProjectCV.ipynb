# %% [markdown]
# Load data set

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

train_data = pd.read_csv("csvTrainImages 13440x1024.csv").values.reshape(-1, 32, 32, 1).astype('float32')
train_labels = pd.read_csv("csvTrainLabel 13440x1.csv").values.flatten()
test_data = pd.read_csv("csvTestImages 3360x1024.csv").values.reshape(-1, 32, 32, 1).astype('float32')
test_labels = pd.read_csv("csvTestLabel 3360x1.csv").values.flatten()
print(train_data.shape)
# Out:
# (13439, 32, 32, 1)

# %% [markdown]
# Build our CNN.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator


# Define the model
model = Sequential()

# Convolutional layers
model.add(Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 1), padding='same', name='conv2d1'))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', name='conv2d2'))
model.add(MaxPooling2D((2, 2), name='maxpooling2d1'))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same', name='conv2d3'))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', name='conv2d4'))
model.add(MaxPooling2D((2, 2), name='maxpooling2d2'))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same', name='conv2d5'))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', name='conv2d6'))
model.add(MaxPooling2D((2, 2), name='maxpooling2d3'))

model.add(Dropout(0.5, name='dropout1'))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same', name='conv2d7'))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', name='conv2d8'))
model.add(MaxPooling2D((2, 2), name='maxpooling2d4'))

model.add(Dropout(0.5, name='dropout2'))

# Flatten layer
model.add(Flatten(name='flatten1'))

# Dense layers
model.add(Dense(32, activation='relu', name='dense1'))
model.add(Dense(64, activation='relu', name='dense2'))
model.add(Dropout(0.5, name='dropout3'))

# Output layer
model.add(Dense(28, activation='softmax', name='dense3'))

custom_optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=custom_optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

datagen = ImageDataGenerator(
rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=False,
    vertical_flip=False,
    fill_mode='wrap'
)
val_datagen = ImageDataGenerator()

# Display the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d1 (Conv2D)            (None, 32, 32, 64)        640
#
#  conv2d2 (Conv2D)            (None, 32, 32, 64)        36928
#
#  maxpooling2d1 (MaxPooling2  (None, 16, 16, 64)        0
#  D)
#
#  conv2d3 (Conv2D)            (None, 16, 16, 64)        36928
#
#  conv2d4 (Conv2D)            (None, 16, 16, 64)        36928
#
#  maxpooling2d2 (MaxPooling2  (None, 8, 8, 64)          0
#  D)
#
#  conv2d5 (Conv2D)            (None, 8, 8, 64)          36928
#
#  conv2d6 (Conv2D)            (None, 8, 8, 64)          36928
#
#  maxpooling2d3 (MaxPooling2  (None, 4, 4, 64)          0
#  D)
#
#  dropout1 (Dropout)          (None, 4, 4, 64)          0
#
#  conv2d7 (Conv2D)            (None, 4, 4, 64)          36928
#
#  conv2d8 (Conv2D)            (None, 4, 4, 64)          36928
#
#  maxpooling2d4 (MaxPooling2  (None, 2, 2, 64)          0
#  D)
#
#  dropout2 (Dropout)          (None, 2, 2, 64)          0
#
#  flatten1 (Flatten)          (None, 256)               0
#
#  dense1 (Dense)              (None, 32)                8224
#
#  dense2 (Dense)              (None, 64)                2112
#
#  dropout3 (Dropout)          (None, 64)                0
#
#  dense3 (Dense)              (None, 28)                1820
#
# =================================================================
# Total params: 271292 (1.03 MB)
# Trainable params: 271292 (1.03 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Task 1

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
# prompt: train the CNN an evaluate the metrics
train_labels_one_hot = to_categorical(train_labels - 1, num_classes=28)
train_data4, val_data, train_labels_one_hot, val_labels_one_hot = train_test_split(
   train_data, train_labels_one_hot, test_size=0.2, shuffle=True
)

history = model.fit(
    train_data4, train_labels_one_hot,
    epochs=50,
    validation_data=(val_data, val_labels_one_hot),
)

test_labels_one_hot = to_categorical(test_labels - 1, num_classes=28)
test_loss, test_acc = model.evaluate(test_data, test_labels_one_hot)
print(f'Test accuracy: {test_acc}')
model.save('my_CNN_ND.h5')
# Out:
# Epoch 1/50
# 336/336 [==============================] - 14s 13ms/step - loss: 3.3410 - accuracy: 0.0340 - val_loss: 3.2454 - val_accuracy: 0.0580
# Epoch 2/50
# 336/336 [==============================] - 4s 11ms/step - loss: 3.2559 - accuracy: 0.0541 - val_loss: 2.8529 - val_accuracy: 0.1198
# Epoch 3/50
# 336/336 [==============================] - 3s 10ms/step - loss: 2.4486 - accuracy: 0.1958 - val_loss: 1.6035 - val_accuracy: 0.3821
# Epoch 4/50
# 336/336 [==============================] - 3s 9ms/step - loss: 1.6619 - accuracy: 0.3905 - val_loss: 1.2038 - val_accuracy: 0.5052
# Epoch 5/50
# 336/336 [==============================] - 3s 9ms/step - loss: 1.2521 - accuracy: 0.5032 - val_loss: 0.8344 - val_accuracy: 0.6429
# Epoch 6/50
# 336/336 [==============================] - 4s 11ms/step - loss: 1.0055 - accuracy: 0.5806 - val_loss: 0.7318 - val_accuracy: 0.6607
# Epoch 7/50
# 336/336 [==============================] - 3s 9ms/step - loss: 0.8844 - accuracy: 0.6298 - val_loss: 0.6727 - val_accuracy: 0.7184
# Epoch 8/50
# 336/336 [==============================] - 3s 9ms/step - loss: 0.8044 - accuracy: 0.6697 - val_loss: 0.5898 - val_accuracy: 0.7645
# Epoch 9/50
# 336/336 [==============================] - 3s 10ms/step - loss: 0.6782 - accuracy: 0.7365 - val_loss: 0.4576 - val_accuracy: 0.8333
# Epoch 10/50
# 336/336 [==============================] - 3s 10ms/step - loss: 0.5843 - accuracy: 0.7703 - val_loss: 0.4311 - val_accuracy: 0.8356
# Epoch 11/50
# 336/336 [==============================] - 3s 9ms/step - loss: 0.5451 - accuracy: 0.7933 - val_loss: 0.7290 - val_accuracy: 0.7801
# Epoch 12/50
# 336/336 [==============================] - 3s 10ms/step - loss: 0.5006 - accuracy: 0.8156 - val_loss: 0.2976 - val_accuracy: 0.8947
# Epoch 13/50
# 336/336 [==============================] - 4s 12ms/step - loss: 0.4302 - accuracy: 0.8390 - val_loss: 0.3062 - val_accuracy: 0.8951
# Epoch 14/50
# 336/336 [==============================] - 3s 10ms/step - loss: 0.3982 - accuracy: 0.8620 - val_loss: 0.3334 - val_accuracy: 0.9170
# Epoch 15/50
# 336/336 [==============================] - 3s 9ms/step - loss: 0.3677 - accuracy: 0.8770 - val_loss: 0.2620 - val_accuracy: 0.9275
# Epoch 16/50
# 336/336 [==============================] - 3s 10ms/step - loss: 0.3421 - accuracy: 0.8929 - val_loss: 0.2791 - val_accuracy: 0.9282
# Epoch 17/50
# 336/336 [==============================] - 5s 15ms/step - loss: 0.3225 - accuracy: 0.8995 - val_loss: 0.2424 - val_accuracy: 0.9330
# Epoch 18/50
# 336/336 [==============================] - 3s 9ms/step - loss: 0.1386 - accuracy: 0.9636 - val_loss: 0.3180 - val_accuracy: 0.9453
# Epoch 39/50
# 336/336 [==============================] - 4s 11ms/step - loss: 0.2069 - accuracy: 0.9487 - val_loss: 0.2041 - val_accuracy: 0.9587
# Epoch 40/50
# 336/336 [==============================] - 3s 9ms/step - loss: 0.1457 - accuracy: 0.9630 - val_loss: 0.3600 - val_accuracy: 0.9371
# Epoch 41/50
# 336/336 [==============================] - 3s 10ms/step - loss: 0.1596 - accuracy: 0.9611 - val_loss: 0.2832 - val_accuracy: 0.9539
# Epoch 42/50
# 336/336 [==============================] - 3s 10ms/step - loss: 0.1451 - accuracy: 0.9642 - val_loss: 0.2318 - val_accuracy: 0.9598
# Epoch 43/50
# 336/336 [==============================] - 4s 13ms/step - loss: 0.1392 - accuracy: 0.9649 - val_loss: 0.2524 - val_accuracy: 0.9524
# Epoch 44/50
# 336/336 [==============================] - 3s 9ms/step - loss: 0.1745 - accuracy: 0.9559 - val_loss: 0.2090 - val_accuracy: 0.9587
# Epoch 45/50
# 336/336 [==============================] - 3s 10ms/step - loss: 0.1580 - accuracy: 0.9616 - val_loss: 0.2177 - val_accuracy: 0.9635
# Epoch 46/50
# 336/336 [==============================] - 3s 10ms/step - loss: 0.1917 - accuracy: 0.9514 - val_loss: 0.2466 - val_accuracy: 0.9509
# Epoch 47/50
# 336/336 [==============================] - 3s 10ms/step - loss: 0.1706 - accuracy: 0.9566 - val_loss: 0.2346 - val_accuracy: 0.9591
# Epoch 48/50
# 336/336 [==============================] - 3s 9ms/step - loss: 0.1649 - accuracy: 0.9576 - val_loss: 0.2690 - val_accuracy: 0.9568
# Epoch 49/50
# 336/336 [==============================] - 3s 9ms/step - loss: 0.1698 - accuracy: 0.9604 - val_loss: 0.2919 - val_accuracy: 0.9446
# Epoch 50/50
# 336/336 [==============================] - 4s 11ms/step - loss: 0.1407 - accuracy: 0.9641 - val_loss: 0.2542 - val_accuracy: 0.9591
# 105/105 [==============================] - 1s 4ms/step - loss: 0.2837 - accuracy: 0.9601
# Test accuracy: 0.960107147693634
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Results

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))

# Plot Training Loss & Validation Loss vs. Epoch
plt.subplot(2, 3, 1)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training Loss & Validation Loss vs. Epoch')

# Plot Training Accuracy Validation Accuracy vs. Epoch
plt.subplot(2, 3, 2)
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training Accuracy Validation Accuracy vs. Epoch')

# Plot training loss vs. epoch
plt.subplot(2, 3, 3)
plt.plot(history.history['loss'], label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training Loss vs. Epoch')

# Plot validation loss vs. epoch
plt.subplot(2, 3, 4)
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Validation Loss vs. Epoch')


# Plot training accuracy vs. epoch
plt.subplot(2, 3, 5)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training Accuracy vs. Epoch')
# Plot testing accuracy vs. epoch
plt.subplot(2, 3, 6)
plt.plot(history.history['val_accuracy'], label='Testing Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Testing Accuracy vs. Epoch')

# Show the combined figure
plt.tight_layout()
plt.show()

# %% [markdown]
# Task 2

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
# prompt: train the CNN an evaluate the metrics
train_labels_one_hot = to_categorical(train_labels - 1, num_classes=28)
train_data2, val_data, train_labels_one_hot, val_labels_one_hot = train_test_split(
   train_data, train_labels_one_hot, test_size=0.2, shuffle=True
)
history = model.fit(
    datagen.flow(train_data2, train_labels_one_hot),
    epochs=50,
    validation_data=datagen.flow(val_data, val_labels_one_hot),
)


test_labels_one_hot = to_categorical(test_labels - 1, num_classes=28)
test_loss, test_acc = model.evaluate(datagen.flow(test_data, test_labels_one_hot))
print(f'Test accuracy: {test_acc}')
model.save('my_CNN_YD.h5')
# Out:
# Epoch 1/50
# 336/336 [==============================] - 14s 22ms/step - loss: 3.3377 - accuracy: 0.0392 - val_loss: 3.2871 - val_accuracy: 0.0625
# Epoch 2/50
# 336/336 [==============================] - 8s 22ms/step - loss: 3.0966 - accuracy: 0.0755 - val_loss: 2.6990 - val_accuracy: 0.1034
# Epoch 3/50
# 336/336 [==============================] - 7s 21ms/step - loss: 2.5693 - accuracy: 0.1138 - val_loss: 2.3368 - val_accuracy: 0.1559
# Epoch 4/50
# 336/336 [==============================] - 6s 18ms/step - loss: 2.2831 - accuracy: 0.1740 - val_loss: 2.0051 - val_accuracy: 0.2124
# Epoch 5/50
# 336/336 [==============================] - 7s 21ms/step - loss: 2.0621 - accuracy: 0.2337 - val_loss: 1.7319 - val_accuracy: 0.3400
# Epoch 6/50
# 336/336 [==============================] - 7s 20ms/step - loss: 1.6972 - accuracy: 0.3536 - val_loss: 1.6200 - val_accuracy: 0.4260
# Epoch 7/50
# 336/336 [==============================] - 8s 24ms/step - loss: 1.4778 - accuracy: 0.4314 - val_loss: 1.1336 - val_accuracy: 0.5365
# Epoch 8/50
# 336/336 [==============================] - 7s 21ms/step - loss: 1.2708 - accuracy: 0.5032 - val_loss: 0.9951 - val_accuracy: 0.5666
# Epoch 9/50
# 336/336 [==============================] - 6s 19ms/step - loss: 1.1405 - accuracy: 0.5422 - val_loss: 0.9037 - val_accuracy: 0.6503
# Epoch 10/50
# 336/336 [==============================] - 7s 21ms/step - loss: 1.0087 - accuracy: 0.6064 - val_loss: 0.7709 - val_accuracy: 0.7150
# Epoch 11/50
# 336/336 [==============================] - 6s 19ms/step - loss: 0.9267 - accuracy: 0.6532 - val_loss: 0.6453 - val_accuracy: 0.7604
# Epoch 12/50
# 336/336 [==============================] - 7s 21ms/step - loss: 0.7900 - accuracy: 0.7068 - val_loss: 0.6616 - val_accuracy: 0.7396
# Epoch 13/50
# 336/336 [==============================] - 7s 20ms/step - loss: 0.7155 - accuracy: 0.7260 - val_loss: 0.5248 - val_accuracy: 0.7995
# Epoch 14/50
# 336/336 [==============================] - 7s 20ms/step - loss: 0.6395 - accuracy: 0.7583 - val_loss: 0.4607 - val_accuracy: 0.8296
# Epoch 15/50
# 336/336 [==============================] - 7s 21ms/step - loss: 0.6233 - accuracy: 0.7658 - val_loss: 0.5172 - val_accuracy: 0.7950
# Epoch 16/50
# 336/336 [==============================] - 6s 19ms/step - loss: 0.5873 - accuracy: 0.7861 - val_loss: 0.3830 - val_accuracy: 0.8620
# Epoch 17/50
# 336/336 [==============================] - 6s 19ms/step - loss: 0.5478 - accuracy: 0.8025 - val_loss: 0.3717 - val_accuracy: 0.8810
# Epoch 18/50
# 336/336 [==============================] - 6s 18ms/step - loss: 0.5107 - accuracy: 0.8285 - val_loss: 0.3324 - val_accuracy: 0.8921
# Epoch 39/50
# 336/336 [==============================] - 7s 20ms/step - loss: 0.2745 - accuracy: 0.9362 - val_loss: 0.1732 - val_accuracy: 0.9598
# Epoch 40/50
# 336/336 [==============================] - 8s 23ms/step - loss: 0.2683 - accuracy: 0.9336 - val_loss: 0.1932 - val_accuracy: 0.9587
# Epoch 41/50
# 336/336 [==============================] - 6s 19ms/step - loss: 0.2523 - accuracy: 0.9401 - val_loss: 0.2134 - val_accuracy: 0.9513
# Epoch 42/50
# 336/336 [==============================] - 7s 22ms/step - loss: 0.2904 - accuracy: 0.9304 - val_loss: 0.2212 - val_accuracy: 0.9483
# Epoch 43/50
# 336/336 [==============================] - 6s 19ms/step - loss: 0.2851 - accuracy: 0.9304 - val_loss: 0.1960 - val_accuracy: 0.9561
# Epoch 44/50
# 336/336 [==============================] - 7s 21ms/step - loss: 0.2445 - accuracy: 0.9394 - val_loss: 0.2626 - val_accuracy: 0.9427
# Epoch 45/50
# 336/336 [==============================] - 6s 19ms/step - loss: 0.2313 - accuracy: 0.9425 - val_loss: 0.2044 - val_accuracy: 0.9598
# Epoch 46/50
# 336/336 [==============================] - 6s 19ms/step - loss: 0.2578 - accuracy: 0.9407 - val_loss: 0.2195 - val_accuracy: 0.9483
# Epoch 47/50
# 336/336 [==============================] - 6s 19ms/step - loss: 0.2371 - accuracy: 0.9427 - val_loss: 0.2017 - val_accuracy: 0.9524
# Epoch 48/50
# 336/336 [==============================] - 8s 25ms/step - loss: 0.2461 - accuracy: 0.9390 - val_loss: 0.1938 - val_accuracy: 0.9572
# Epoch 49/50
# 336/336 [==============================] - 6s 19ms/step - loss: 0.2661 - accuracy: 0.9344 - val_loss: 0.2280 - val_accuracy: 0.9602
# Epoch 50/50
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2645 - accuracy: 0.9387 - val_loss: 0.1716 - val_accuracy: 0.9606
# 105/105 [==============================] - 1s 13ms/step - loss: 0.1699 - accuracy: 0.9601
# Test accuracy: 0.960107147693634
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Results

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))

# Plot Training Loss & Validation Loss vs. Epoch
plt.subplot(2, 3, 1)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training Loss & Validation Loss vs. Epoch')

# Plot Training Accuracy Validation Accuracy vs. Epoch
plt.subplot(2, 3, 2)
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training Accuracy Validation Accuracy vs. Epoch')

# Plot training loss vs. epoch
plt.subplot(2, 3, 3)
plt.plot(history.history['loss'], label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training Loss vs. Epoch')

# Plot validation loss vs. epoch
plt.subplot(2, 3, 4)
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Validation Loss vs. Epoch')


# Plot training accuracy vs. epoch
plt.subplot(2, 3, 5)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training Accuracy vs. Epoch')
# Plot testing accuracy vs. epoch
plt.subplot(2, 3, 6)
plt.plot(history.history['val_accuracy'], label='Testing Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Testing Accuracy vs. Epoch')

# Show the combined figure
plt.tight_layout()
plt.show()

# %% [markdown]
# Task 3

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Reshape
from tensorflow.keras.utils import to_categorical
import pydot
from sklearn.model_selection import train_test_split
# prompt: train the CNN an evaluate the metrics
train_labels_one_hot = to_categorical(train_labels - 1, num_classes=28)
train_data3, val_data, train_labels_one_hot, val_labels_one_hot = train_test_split(
   train_data, train_labels_one_hot, test_size=0.2, shuffle=True
)

train_data_rgb = np.repeat(train_data3, 3, axis=-1)
val_data_rgb = np.repeat(val_data, 3, axis=-1)
print(train_data_rgb.shape)
test_data_rgb = np.repeat(test_data, 3, axis=-1)
print(test_data_rgb.shape)





base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(32, 32, 3))



model2 = Sequential()
model2.add(base_model)
model2.add(Flatten())
model2.add(Dense(256, activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(28, activation='softmax'))
custom_optimizer2 = Adam(learning_rate=0.001)
model2.compile(optimizer=custom_optimizer2, loss='categorical_crossentropy', metrics=['accuracy'])
model2.summary()

history = model2.fit(
    datagen.flow(train_data_rgb, train_labels_one_hot),
    epochs=50,
    validation_data=(val_data_rgb, val_labels_one_hot),
)


test_labels_one_hot = to_categorical(test_labels - 1, num_classes=28)
test_loss, test_acc = model2.evaluate(test_data_rgb, test_labels_one_hot)
print(f'Test accuracy: {test_acc}')
model2.save('my_CNN_ResNet50.h5')
# Out:
# (10751, 32, 32, 3)
# (3359, 32, 32, 3)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 1, 1, 2048)        23587712
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 28)                7196
#
# =================================================================
# Total params: 24119452 (92.01 MB)
# Trainable params: 24066332 (91.81 MB)
# Non-trainable params: 53120 (207.50 KB)
# _________________________________________________________________
# Epoch 1/50
# 336/336 [==============================] - 59s 70ms/step - loss: 2.3353 - accuracy: 0.3617 - val_loss: 3.3797 - val_accuracy: 0.3170
# Epoch 2/50
# 336/336 [==============================] - 21s 62ms/step - loss: 1.2733 - accuracy: 0.6178 - val_loss: 0.9033 - val_accuracy: 0.7202
# Epoch 3/50
# 336/336 [==============================] - 20s 61ms/step - loss: 1.2209 - accuracy: 0.6380 - val_loss: 1.7085 - val_accuracy: 0.5592
# Epoch 4/50
# 336/336 [==============================] - 20s 58ms/step - loss: 1.0054 - accuracy: 0.6855 - val_loss: 2.2017 - val_accuracy: 0.5975
# Epoch 5/50
# 336/336 [==============================] - 21s 63ms/step - loss: 1.0122 - accuracy: 0.6861 - val_loss: 1.5585 - val_accuracy: 0.5964
# Epoch 6/50
# 336/336 [==============================] - 20s 60ms/step - loss: 1.1218 - accuracy: 0.6496 - val_loss: 2.3280 - val_accuracy: 0.3352
# Epoch 7/50
# 336/336 [==============================] - 20s 59ms/step - loss: 0.9316 - accuracy: 0.7072 - val_loss: 1.5749 - val_accuracy: 0.6804
# Epoch 8/50
# 336/336 [==============================] - 20s 60ms/step - loss: 0.6728 - accuracy: 0.7940 - val_loss: 0.4193 - val_accuracy: 0.8583
# Epoch 9/50
# 336/336 [==============================] - 20s 58ms/step - loss: 0.6267 - accuracy: 0.8085 - val_loss: 0.4947 - val_accuracy: 0.8475
# Epoch 10/50
# 336/336 [==============================] - 21s 61ms/step - loss: 0.7978 - accuracy: 0.7577 - val_loss: 0.7045 - val_accuracy: 0.7746
# Epoch 11/50
# 336/336 [==============================] - 21s 62ms/step - loss: 0.7778 - accuracy: 0.7613 - val_loss: 0.4971 - val_accuracy: 0.8516
# Epoch 12/50
# 336/336 [==============================] - 21s 61ms/step - loss: 1.1108 - accuracy: 0.6559 - val_loss: 1.2668 - val_accuracy: 0.6276
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training Accuracy Validation Accuracy vs. Epoch')

# Plot training loss vs. epoch
plt.subplot(2, 3, 3)
plt.plot(history.history['loss'], label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training Loss vs. Epoch')

# Plot validation loss vs. epoch
plt.subplot(2, 3, 4)
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Validation Loss vs. Epoch')


# Plot training accuracy vs. epoch
plt.subplot(2, 3, 5)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training Accuracy vs. Epoch')
# Plot testing accuracy vs. epoch
plt.subplot(2, 3, 6)
plt.plot(history.history['val_accuracy'], label='Testing Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Testing Accuracy vs. Epoch')

# Show the combined figure
plt.tight_layout()
plt.show()

# %% [markdown]
# Task 4

# %%
import tensorflow as tf
from sklearn.metrics import accuracy_score
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import cv2
import numpy as np
import json

# Load your pre-trained CNN model from the HDF5 file
with open('precnn.json', 'r') as json_file:
    json_config = json_file.read()

modelp = tf.keras.models.model_from_json(json_config)

# Load the model weights from the HDF5 file
modelp.load_weights('precnn.h5')

modelp.summary()

# Freeze all layers in the pre-trained model
for layer in modelp.layers:
    layer.trainable = False

# Add a new dense layer with the desired number of classes (28 in this case)
num_classes = 28

fine_tuned_model = tf.keras.Sequential([
    modelp,
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# Split the data
train_data1, val_data, train_labels_one_hot, val_labels_one_hot = train_test_split(
    train_data, to_categorical(train_labels - 1, num_classes=28), test_size=0.2, shuffle=True
)

# Data augmentation for the training set
datagen2 = ImageDataGenerator(
    rescale=1/255,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=False,
    vertical_flip=False,
    fill_mode='wrap'
)




# Repeat RGB channels
train_data_rgb = np.repeat(train_data1, 3, axis=-1)
val_data_rgb = np.repeat(val_data, 3, axis=-1)
test_data_rgb = np.repeat(test_data, 3, axis=-1)

# Compile the model with a custom optimizer
custom_optimizer2 = Adam(learning_rate=0.001)
fine_tuned_model.compile(optimizer=custom_optimizer2, loss='categorical_crossentropy', metrics=['accuracy'])

# Evaluate on the test set before fine-tuning
test_labels_one_hot = to_categorical(test_labels - 1, num_classes=28)
test_loss, test_acc = fine_tuned_model.evaluate(test_data_rgb/255, test_labels_one_hot)
print(f'Initial Test accuracy: {test_acc}')

val_datagen = ImageDataGenerator(rescale=1/255)
test_datagen = ImageDataGenerator(rescale=1/255)

# Flow validation and test data using the corresponding data generators
val_data_gen = val_datagen.flow(val_data_rgb, val_labels_one_hot)
test_data_gen = test_datagen.flow(test_data_rgb, test_labels_one_hot)


# Fine-tune the model
history2 = fine_tuned_model.fit(
    datagen2.flow(train_data_rgb, train_labels_one_hot),
    epochs=10,
    validation_data=val_data_gen,
)
for layer in fine_tuned_model.layers:  # Unfreeze the all layers
    layer.trainable = True

custom_optimizer2 = Adam(learning_rate=0.001)
fine_tuned_model.compile(optimizer=custom_optimizer2, loss='categorical_crossentropy', metrics=['accuracy'])

history = fine_tuned_model.fit(
    datagen2.flow(train_data_rgb, train_labels_one_hot),
    epochs=40,
    validation_data=val_data_gen,
)
# Evaluate on the test set after fine-tuning
test_loss, test_acc = fine_tuned_model.evaluate(test_data_gen)
print(f'Final Test accuracy: {test_acc}')
fine_tuned_model.summary()
fine_tuned_model.save('my_CNN_TL.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        896
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 64)        36928
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 64)        36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 5, 5, 64)          0
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dense_1 (Dense)             (None, 128)               204928
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 304110 (1.16 MB)
# Trainable params: 304110 (1.16 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 105/105 [==============================] - 1s 5ms/step - loss: 3.3346 - accuracy: 0.0429
# Initial Test accuracy: 0.04286990314722061
# Epoch 1/10
# 336/336 [==============================] - 10s 26ms/step - loss: 3.1966 - accuracy: 0.1079 - val_loss: 2.9023 - val_accuracy: 0.1994
# Epoch 2/10
# 336/336 [==============================] - 7s 22ms/step - loss: 2.9422 - accuracy: 0.1471 - val_loss: 2.6591 - val_accuracy: 0.2269
# Epoch 3/10
# 336/336 [==============================] - 8s 24ms/step - loss: 2.8709 - accuracy: 0.1514 - val_loss: 2.5837 - val_accuracy: 0.2385
# Epoch 4/10
# 336/336 [==============================] - 10s 29ms/step - loss: 2.8190 - accuracy: 0.1635 - val_loss: 2.5389 - val_accuracy: 0.2459
# Epoch 5/10
# 336/336 [==============================] - 9s 27ms/step - loss: 2.7932 - accuracy: 0.1667 - val_loss: 2.5067 - val_accuracy: 0.2504
# Epoch 6/10
# 336/336 [==============================] - 8s 24ms/step - loss: 2.7930 - accuracy: 0.1698 - val_loss: 2.4981 - val_accuracy: 0.2470
# Epoch 7/10
# 336/336 [==============================] - 8s 23ms/step - loss: 2.7810 - accuracy: 0.1727 - val_loss: 2.4841 - val_accuracy: 0.2589
# Epoch 8/10
# 336/336 [==============================] - 9s 26ms/step - loss: 2.7657 - accuracy: 0.1793 - val_loss: 2.4678 - val_accuracy: 0.2679
# Epoch 9/10
# 336/336 [==============================] - 8s 25ms/step - loss: 2.7597 - accuracy: 0.1782 - val_loss: 2.4575 - val_accuracy: 0.2727
# Epoch 10/10
# 336/336 [==============================] - 11s 33ms/step - loss: 2.7456 - accuracy: 0.1821 - val_loss: 2.4407 - val_accuracy: 0.2719
# Epoch 1/40
# 336/336 [==============================] - 12s 28ms/step - loss: 1.6776 - accuracy: 0.4093 - val_loss: 0.9675 - val_accuracy: 0.5755
# Epoch 2/40
# 336/336 [==============================] - 8s 24ms/step - loss: 1.0648 - accuracy: 0.5706 - val_loss: 0.7034 - val_accuracy: 0.6994
# Epoch 3/40
# 336/336 [==============================] - 9s 27ms/step - loss: 0.8360 - accuracy: 0.6617 - val_loss: 0.5364 - val_accuracy: 0.7805
# Epoch 4/40
# 336/336 [==============================] - 9s 27ms/step - loss: 0.6505 - accuracy: 0.7408 - val_loss: 0.4558 - val_accuracy: 0.8006
# Epoch 5/40
# 336/336 [==============================] - 8s 23ms/step - loss: 0.5448 - accuracy: 0.7944 - val_loss: 0.3572 - val_accuracy: 0.8449
# Epoch 6/40
# 336/336 [==============================] - 12s 35ms/step - loss: 0.4768 - accuracy: 0.8244 - val_loss: 0.3439 - val_accuracy: 0.8635
# Epoch 7/40
# 336/336 [==============================] - 9s 27ms/step - loss: 0.4108 - accuracy: 0.8514 - val_loss: 0.3086 - val_accuracy: 0.8810
# Epoch 28/40
# 336/336 [==============================] - 8s 25ms/step - loss: 0.1361 - accuracy: 0.9634 - val_loss: 0.1310 - val_accuracy: 0.9676
# Epoch 29/40
# 336/336 [==============================] - 12s 34ms/step - loss: 0.1256 - accuracy: 0.9640 - val_loss: 0.1591 - val_accuracy: 0.9650
# Epoch 30/40
# 336/336 [==============================] - 8s 25ms/step - loss: 0.1240 - accuracy: 0.9678 - val_loss: 0.1276 - val_accuracy: 0.9699
# Epoch 31/40
# 336/336 [==============================] - 10s 28ms/step - loss: 0.1327 - accuracy: 0.9622 - val_loss: 0.1290 - val_accuracy: 0.9665
# Epoch 32/40
# 336/336 [==============================] - 9s 27ms/step - loss: 0.1329 - accuracy: 0.9623 - val_loss: 0.1219 - val_accuracy: 0.9695
# Epoch 33/40
# 336/336 [==============================] - 8s 24ms/step - loss: 0.1306 - accuracy: 0.9624 - val_loss: 0.1268 - val_accuracy: 0.9673
# Epoch 34/40
# 336/336 [==============================] - 8s 24ms/step - loss: 0.1301 - accuracy: 0.9648 - val_loss: 0.1311 - val_accuracy: 0.9688
# Epoch 35/40
# 336/336 [==============================] - 9s 27ms/step - loss: 0.1215 - accuracy: 0.9662 - val_loss: 0.1209 - val_accuracy: 0.9669
# Epoch 36/40
# 336/336 [==============================] - 9s 27ms/step - loss: 0.1342 - accuracy: 0.9615 - val_loss: 0.1152 - val_accuracy: 0.9714
# Epoch 37/40
# 336/336 [==============================] - 8s 24ms/step - loss: 0.1255 - accuracy: 0.9660 - val_loss: 0.1193 - val_accuracy: 0.9695
# Epoch 38/40
# 336/336 [==============================] - 8s 25ms/step - loss: 0.1270 - accuracy: 0.9646 - val_loss: 0.1358 - val_accuracy: 0.9654
# Epoch 39/40
# 336/336 [==============================] - 9s 27ms/step - loss: 0.1186 - accuracy: 0.9661 - val_loss: 0.1324 - val_accuracy: 0.9684
# Epoch 40/40
# 336/336 [==============================] - 10s 30ms/step - loss: 0.1204 - accuracy: 0.9660 - val_loss: 0.1132 - val_accuracy: 0.9728
# 105/105 [==============================] - 1s 6ms/step - loss: 0.1129 - accuracy: 0.9726
# Final Test accuracy: 0.9726108908653259
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 46)                304110
#
#  flatten_1 (Flatten)         (None, 46)                0
#
#  dense_2 (Dense)             (None, 256)               12032
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 28)                7196
#
# =================================================================
# Total params: 323338 (1.23 MB)
# Trainable params: 323338 (1.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Results

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))

# Plot Training Loss & Validation Loss vs. Epoch
plt.subplot(2, 3, 1)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training Loss & Validation Loss vs. Epoch')

# Plot Training Accuracy Validation Accuracy vs. Epoch
plt.subplot(2, 3, 2)
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training Accuracy Validation Accuracy vs. Epoch')

# Plot training loss vs. epoch
plt.subplot(2, 3, 3)
plt.plot(history.history['loss'], label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training Loss vs. Epoch')

# Plot validation loss vs. epoch
plt.subplot(2, 3, 4)
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Validation Loss vs. Epoch')


# Plot training accuracy vs. epoch
plt.subplot(2, 3, 5)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training Accuracy vs. Epoch')
# Plot testing accuracy vs. epoch
plt.subplot(2, 3, 6)
plt.plot(history.history['val_accuracy'], label='Testing Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Testing Accuracy vs. Epoch')

# Show the combined figure
plt.tight_layout()
plt.show()
